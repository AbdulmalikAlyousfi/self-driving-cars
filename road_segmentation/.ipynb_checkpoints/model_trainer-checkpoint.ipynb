# %%
from fastai.vision.all import *

# %%
Path.cwd()
# Out:
# Path('/home/fahad/learning/python_codes/fastai/autonomous_car/src')

# %%
BASE_DIR = Path.cwd().parent

# %%
BASE_DIR
# Out:
# Path('/home/fahad/learning/python_codes/fastai/autonomous_car')

# %%
data_path = BASE_DIR / 'data/kitti'

# %%
data_path
# Out:
# Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti')

# %%
mask_file = data_path / 'training/gt_image_2/umm_road_000038.png'
mask = PILMask.create(mask_file)
mask
# Out:
# PILMask mode=L size=1242x375

# %%
unique_values = np.unique(mask)
print(unique_values)
# Out:
# [  0  76 105]

# %%
mask_copy = np.where(np.array(mask) == 105, 1, 0)
plt.imshow(mask_copy)

# %%
lbl_names = get_image_files(data_path / 'training/gt_image_2')
print(type(lbl_names))
lbl_names
# Out:
# <class 'fastcore.foundation.L'>
# (#384) [Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/umm_road_000028.png'),Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/um_road_000027.png'),Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/um_lane_000021.png'),Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/umm_road_000045.png'),Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/um_road_000094.png'),Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/umm_road_000005.png'),Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/umm_road_000063.png'),Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/um_lane_000018.png'),Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/umm_road_000004.png'),Path('/home/fahad/learning/python_codes/fastai/autonomous_car/data/kitti/training/gt_image_2/um_lane_000072.png')...]

# %%
def n_codes(fnames, is_partial=False):
    "Gather the codes from a list of `fnames`"
    vals = set()
    if is_partial:
        random.shuffle(fnames)
        fnames = fnames[:10]
    for fname in fnames:
        msk = np.array(PILMask.create(fname))
        for val in np.unique(msk):
            if val not in vals:
                vals.add(val)
    vals = list(vals)
    p2c = dict()
    for i,val in enumerate(vals):
        p2c[i] = vals[i]
    return p2c

# %%
p2c = n_codes(lbl_names)
p2c
# Out:
# {0: 0, 1: 105, 2: 76, 3: 29}

# %%
codes = ['Other Lane', 'Road', 'Background', 'gutter']

# %%
def get_msk(fn, pix2class):
    "Grab a mask from a `filename` and adjust the pixels based on `pix2class`"
    fn = fn.parent.parent/'gt_image_2'/f'{fn.stem.split("_")[0]}_road_{fn.stem.split("_")[-1]}{fn.suffix}'
    msk = np.array(PILMask.create(fn))
#     mx = np.max(msk)
    for i, val in enumerate(pix2class):
        msk[msk==pix2class[i]] = val
    return PILMask.create(msk)

# %%
get_y = lambda o: get_msk(o, p2c)

# %%
file_names = get_image_files(data_path / 'training/image_2')
test_mask = get_y(file_names[9])
plt.imshow(np.array(test_mask))
print(np.unique(test_mask))
# Out:
# [0 1 2 3]

# %%
kitty = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
        get_items=get_image_files,
        splitter=RandomSplitter(),
        get_y=get_y,
        item_tfms=Resize(256))
# kitty = DataBlock(
#         get_items=get_image_files,
#         get_y=lambda o: o.parent.parent/'gt_image_2'/f'{o.stem.split("_")[0]}_lane_{o.stem.split("_")[-1]}{o.suffix}',
#         )

# %%
dls = kitty.dataloaders(data_path / 'training/image_2', bs=4)
dls.show_batch()

# %%
learn = unet_learner(dls, resnet34, metrics=Dice)

# %%
learn.fine_tune(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.444732</td>
#       <td>0.872835</td>
#       <td>1.799166</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.229226</td>
#       <td>0.191386</td>
#       <td>1.771793</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.186546</td>
#       <td>0.212094</td>
#       <td>1.741246</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.132348</td>
#       <td>0.154818</td>
#       <td>1.754009</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()

# %%
learn.predict??
# Out:
# Signature: learn.predict(item, rm_type_tfms=None, with_input=False)
# Docstring: Prediction on `item`, fully decoded, loss function decoded and probabilities
# Source:
#     def predict(self, item, rm_type_tfms=None, with_input=False):
#         dl = self.dls.test_dl([item], rm_type_tfms=rm_type_tfms, num_workers=0)
#         inp,preds,_,dec_preds = self.get_preds(dl=dl, with_input=True, with_decoded=True)
#         i = getattr(self.dls, 'n_inp', -1)
#         inp = (inp,) if i==1 else tuplify(inp)
#         dec = self.dls.decode_batch(inp + tuplify(dec_preds))[0]
#         dec_inp,dec_targ = map(detuplify, [dec[:i],dec[i:]])
#         res = dec_targ,dec_preds[0],preds[0]
#         if with_input: res = (dec_inp,) + res
#         return res
# File:      ~/miniconda3/envs/fastai/lib/python3.8/site-packages/fastai/learner.py
# Type:      method
